# %%
import sys
import pandas as pd

sys.path.append(r"C:\Users\axdrx\OneDrive\Escritorio\TFM\scripts TFM")
import extraccion_udfs as mf

# Cargar artículos
include = pd.read_csv(
    r"C:\Users\axdrx\OneDrive\Escritorio\TFM\Extraccion\estudios_definitivos.csv",
    encoding='utf-8-sig'
)

# Inicializar tablas vacías
reviewed   = pd.DataFrame()
studies_df = mf.create_studies_table()

print(f"Artículos cargados: {len(include)}")
print(include)
# Out:
# Artículos cargados: 14
#                                                Título  \
# 0   Prognostic values of novel biomarkers in patie...
# 1   Genomic profiling in amyloid light-chain amylo...
# 2   Development of an artificial intelligence-base...
# 3   Elevation of Plasmin-α2-plasmin Inhibitor Comp...
# 4   LGE Provides Incremental Prognostic Informatio...
# 5   Metabolomics and machine learning approaches f...
# 6   Red blood cell distribution width is a simple ...
# 7   Growth differentiation factor-15 is a new biom...
# 8   Prognostic Value of Circulating sST2 for the P...
# 9   Prognostic Value of Serum Galectin-3 for Survi...
# 10  Elevation of serum lactate dehydrogenase in AL...
# 11  Novel recurrent chromosomal aberrations detect...
# 12  The Incremental Value of Native T1 Mapping-Der...
# 13  Clinical correlates and prognostic values of p...
#
#                                  DOI  \
# 0         10.1038/s41598-019-48513-6
# 1      10.1080/13506129.2019.1678464
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Kim", include, reviewed, studies_df)
# Out:
# Título: Prognostic values of novel biomarkers in patients with AL amyloidosis
# Autor:  Kim D, Lee GY, Choi JO, Kim K, Kim SJ, Ju ES, Jeon ES
# DOI:    10.1038/s41598-019-48513-6
# ¿Extraer datos de este artículo? (y/n):  Y
# ── Tabla de características generales ───────────────
# Año de publicación:  2019
# Revista:  Scientific Reports
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=73 pacientes con amiloidosis AL
# Técnicas utilizadas:  Proteómica: Inmunoensayo
# ✓ Estudio añadido: Kim2019
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Kim2019:
# Nombre/s del biomarcador:  sST2 (Supresor Soluble de la Tumorigenicidad 2)
# Tipo (proteómico/genómico/imagen/circulante/panel):  Proteómico
# Tipo de muestra (suero/plasma/orina/tejido/imagen):  Plasma
# Propósito/potencial clínico (diagnóstico/pronóstico/monitorización/varios):  Pronóstico
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Yogo", include, reviewed, studies_df)
# Out:
# Título: Red blood cell distribution width is a simple and novel biomarker for survival in light-chain amyloidosis
# Autor:  Yogo T, Okazuka K, Nashimoto J, Uto Y, Sato K, Miyazaki K, Ogura M, Yoshiki Y, Abe Y, Tsukada N, Ishida T, Suzuki K
# DOI:    10.1007/s12185-019-02692-0
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2019
# Revista:  International Journal of Hematology
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=94 pacientes con amiloidosis AL
# Técnicas utilizadas:  Análisis hematológico
# ✓ Estudio añadido: Yogo2019
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Yogo2019:
# Nombre/s del biomarcador:  Amplitud de Distribución Eritrocitaria (RDW)
# Tipo (proteómico/genómico/imagen/circulante/panel):  Circulante
# Tipo de muestra (suero/plasma/orina/tejido/imagen):  Sangre
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Zhao L", include, reviewed, studies_df)
# Out:
# Título: Clinical correlates and prognostic values of pseudoinfarction in cardiac light-chain amyloidosis
# Autor:  Zhao L, Li J, Tian Z, Fang Q
# DOI:    10.1016/j.jjcc.2015.11.004
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2015
# Revista:  Journal of Cardiology
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=110 pacientes con amiloidosis AL
# Técnicas utilizadas:  Electrocardiografía
# ✓ Estudio añadido: Zhao2015
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Zhao2015:
# Nombre/s del biomarcador:  Patrón de pseudoinfarto
# Tipo (proteómico/genómico/imagen/circulante/panel):  Imagen
# Tipo de muestra (suero/plasma/orina/tejido/imagen):  Imagen
# Propósito/potencial clínico (diagnóstico/pronóstico/monitorización/varios):  Pronóstico
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Huang J", include, reviewed, studies_df)
# Out:
# Título: Prognostic Value of Serum Galectin-3 for Survival in Patients with Cardiac Light-Chain Amyloidosis
# Autor:  Huang J, Zhang J, Li J, Tian Z
# DOI:    10.3390/jcdd11070202
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2024
# Revista:  Journal of Cardiovascular Development and Disease
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=60 pacientes con amiloidosis AL
# Técnicas utilizadas:  Proteómica: Inmunoensayo
# ✓ Estudio añadido: Huang2024
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Huang2024:
# Nombre/s del biomarcador:  Galectina-3
# Tipo (proteómico/genómico/imagen/circulante/panel):  Proteómico
# Tipo de muestra (suero/plasma/orina/tejido/imagen):  Suero
# Propósito/potencial clínico (diagnóstico/pronóstico/monitorización/varios):  Pronóstico
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Huang XF", include, reviewed, studies_df)
# Out:
# Título: Genomic profiling in amyloid light-chain amyloidosis reveals mutation profiles associated with overall survival
# Autor:  Huang XF, Jian S, Lu JL, Shen KN, Feng J, Zhang CL, Tian Z, Wang JL, Lei WJ, Cao XX, Zhou DB, Liang ZY, Li J
# DOI:    10.1080/13506129.2019.1678464
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2019
# Revista:  The Journal of Protein Folding Disorders
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=48 pacientes con amiloidosis AL
# Técnicas utilizadas:  Genómica: NGS (secuenciación completa del exoma y secuenciación dirigida de genes) y secuenciación Sanger
# ✓ Estudio añadido: Huang2019
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Huang2019:
# Nombre/s del biomarcador:  Mutaciones génicas en 98 genes
# Tipo (proteómico/genómico/imagen/circulante/panel):  Genómico
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Ishiguro K", include, reviewed, studies_df)
# Out:
# Título: Elevation of Plasmin-α2-plasmin Inhibitor Complex Predicts the Diagnosis of Systemic AL Amyloidosis in Patients with Monoclonal Protein
# Autor:  Ishiguro K, Hayashi T, Yokoyama Y, Aoki Y, Onodera K, Ikeda H, Ishida T, Nakase H
# DOI:    10.2169/internalmedicine.8999-17
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2017
# Revista:  The Japanese Society of Internal Medicine
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=26 pacientes con amiloidosis AL, n=26 pacientes con MM
# Técnicas utilizadas:  Proteómica: aglutinación en látex y turbidimetría
# ✓ Estudio añadido: Ishiguro2017
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Ishiguro2017:
# Nombre/s del biomarcador:  PIC (Complejo Inhibidor Plasmina-α₂-Antiplasmina)
# Tipo (proteómico/genómico/imagen/circulante/panel):  Proteómico
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Muchtar E", include, reviewed, studies_df)
# Out:
# Título: Elevation of serum lactate dehydrogenase in AL amyloidosis reflects tissue damage and is an adverse prognostic marker in patients not eligible for stem cell transplantation
# Autor:  Muchtar E, Dispenzieri A, Lacy MQ, Buadi FK, Kapoor P, Hayman SR, Gonsalves W, Warsame R, Kourelis TV, Chakraborty R, Russell S, Lust JA, Lin Y, Go RS, Zeldenrust S, Dingli D, Leung N, Rajkumar SV, Kyle RA, Kumar SK, Gertz MA
# DOI:    10.1111/bjh.14830
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2017
# Revista:  British Journal of Hematology
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=1019 pacientes con amiloidosis AL
# Técnicas utilizadas:  Proteómica: espectrofotometría
# ✓ Estudio añadido: Muchtar2017
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Muchtar2017:
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Boynton SJ", include, reviewed, studies_df)
# Out:
# Título: LGE Provides Incremental Prognostic Information Over Serum Biomarkers in AL Cardiac Amyloidosis
# Autor:  Boynton SJ, Geske JB, Dispenzieri A, Syed IS, Hanson TJ, Grogan M, Araoz PA
# DOI:    10.1016/j.jcmg.2015.10.027
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2016
# Revista:  Journal of the American College of Cardiology
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=76 pacientes con amiloidosis AL
# Técnicas utilizadas:  Imagen: resonancia magnética cardíaca (CMR)
# ✓ Estudio añadido: Boynton2016
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Boynton2016:
# Nombre/s del biomarcador:  LGE (realce tardío del gadolinio)
# Tipo (proteómico/genómico/imagen/circulante/panel):  Imagen
# Tipo de muestra (suero/plasma/orina/tejido/imagen):  Imagen
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Kastritis", include, reviewed, studies_df)
# Out:
# Título: Growth differentiation factor-15 is a new biomarker for survival and renal outcomes in light chain amyloidosis
# Autor:  Kastritis E, Papassotiriou I, Merlini G, Milani P, Terpos E, Basset M, Akalestos A, Russo F, Psimenou E, Apostolakou F, Roussou M, Gavriatopoulou M, Eleutherakis-Papaiakovou E, Fotiou D, Ziogas DC, Papadopoulou E, Pamboucas C, Dimopoulos MA, Palladini G
# DOI:    10.1182/blood-2017-12-819904
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2018
# Revista:  The American Society of Hematology
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  En una cohorte independiente de evaluación, n=107 pacientes con amiloidosis AL; En una cohorte independiente de validación, n=202 pacientes con amiloidosis AL
# Técnicas utilizadas:  Proteómica: Inmunoensayo
# ✓ Estudio añadido: Kastritis2018
#
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Granzow M", include, reviewed, studies_df)
# Out:
# Título: Novel recurrent chromosomal aberrations detected in clonal plasma cells of light chain amyloidosis patients show potential adverse prognostic effect: first results from a genome-wide copy number array analysis
# Autor:  Granzow M, Hegenbart U, Hinderhofer K, Hose D, Seckinger A, Bochtler T, Hemminki K, Goldschmidt H, Schönland SO, Jauch A
# DOI:    10.3324/haematol.2016.160721
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2017
# Revista:  Haematologica
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=118 pacientes con amiloidosis AL
# Técnicas utilizadas:  Genómica: Array-CGH e iFISH
# ✓ Estudio añadido: Granzow2017
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Granzow2017:
# Nombre/s del biomarcador:  Aberraciones cromosómicas recurrentes
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Ma Q", include, reviewed, studies_df)
# Out:
# Título: The Incremental Value of Native T1 Mapping-Derived Radiomics for The Diagnosis of Amyloid Light-Chain Cardiac Amyloidosis
# Autor:  Ma Q, Chen J, Cao L, Wu X, Tan Z, Liu H
# DOI:    10.1016/j.acra.2024.07.005
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2024
# Revista:  Academic Radiology
# Diseño del estudio:  Caso Control
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=86 pacientes con amiloidosis AL, n=28 controles
# Técnicas utilizadas:  Imagen: resonancia magnética cardíaca (CMR)
# ✓ Estudio añadido: Ma2024
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Ma2024:
# Nombre/s del biomarcador:  Radiómica derivada del mapeo T1 sin contraste
# Tipo (proteómico/genómico/imagen/circulante/panel):  Imagen
# Tipo de muestra (suero/plasma/orina/tejido/imagen):  Imagen
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Xie W", include, reviewed, studies_df)
# Out:
# Título: Metabolomics and machine learning approaches for diagnostic biomarkers screening in systemic light chain amyloidosis
# Autor:  Xie W, Lai Z, Wang Q, Wang W, Wang J, Liu H, Liang Z, Dong Y
# DOI:    10.1007/s00277-025-06302-4
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2025
# Revista:  Annals of Hematology
# Diseño del estudio:  Caso Control
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=70 pacientes con amiloidosis AL, n=48 pacientes con MM, n=29 controles
# Técnicas utilizadas:  Metabolómica: LC-MS
# ✓ Estudio añadido: Xie2025
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Xie2025:
# Nombre/s del biomarcador:  Fitoesfingosina
# Tipo (proteómico/genómico/imagen/circulante/panel):  Metabolómico
# Tipo de muestra (suero/plasma/orina/tejido/imagen):  Plasma
# ...

# %%
include, reviewed, studies_df = mf.review(
    "Yan W", include, reviewed, studies_df)
# Out:
# Título: Development of an artificial intelligence-based early diagnostic system for light-chain amyloidosis
# Autor:  Yan W, Chen J, He T, Xu H, Chen J, Liu X, Zhong L, Li Y, Sun C, Wang X, Gao L, Jin F, Li B, Li C, Wen Y, Chen Z, Liu B, Li J, Wang H
# DOI:    10.1007/s00277-025-06674-7
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2025
# Revista:  Annals of Hematology
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=1355 pacientes con amiloidosis AL
# Técnicas utilizadas:  Proteómica, Inteligencia Artificial (IA)
# ✓ Estudio añadido: Yan2025
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Yan2025:
# Nombre/s del biomarcador:  Modelo de 10 variables: edad, cTnI, NT-proBNP, Crea, ALB, Tbil, ALP, IVS, LVPW, EF
# Tipo (proteómico/genómico/imagen/circulante/panel):  Proteómico
# ...

# %%
print(include["Autores"].tolist())
print(f"\nQuedan {len(include)} artículos por revisar")
# Out:
# []
#
# Quedan 0 artículos por revisar

# %%
print(reviewed["Autores"].tolist())
# Out:
# ['Kim D, Lee GY, Choi JO, Kim K, Kim SJ, Ju ES, Jeon ES', 'Yogo T, Okazuka K, Nashimoto J, Uto Y, Sato K, Miyazaki K, Ogura M, Yoshiki Y, Abe Y, Tsukada N, Ishida T, Suzuki K', 'Zhao L, Li J, Tian Z, Fang Q', 'Huang J, Zhang J, Li J, Tian Z', 'Huang XF, Jian S, Lu JL, Shen KN, Feng J, Zhang CL, Tian Z, Wang JL, Lei WJ, Cao XX, Zhou DB, Liang ZY, Li J', 'Ishiguro K, Hayashi T, Yokoyama Y, Aoki Y, Onodera K, Ikeda H, Ishida T, Nakase H', 'Muchtar E, Dispenzieri A, Lacy MQ, Buadi FK, Kapoor P, Hayman SR, Gonsalves W, Warsame R, Kourelis TV, Chakraborty R, Russell S, Lust JA, Lin Y, Go RS, Zeldenrust S, Dingli D, Leung N, Rajkumar SV, Kyle RA, Kumar SK, Gertz MA', 'Boynton SJ, Geske JB, Dispenzieri A, Syed IS, Hanson TJ, Grogan M, Araoz PA', 'Kastritis E, Papassotiriou I, Merlini G, Milani P, Terpos E, Basset M, Akalestos A, Russo F, Psimenou E, Apostolakou F, Roussou M, Gavriatopoulou M, Eleutherakis-Papaiakovou E, Fotiou D, Ziogas DC, Papadopoulou E, Pamboucas C, Dimopoulos MA, Palladi
# ...

# %%
# Ver que hay en revisados vs. en studies.df porque me falta un artículo por revisar y no lo encuentra
ids_revisados = reviewed["Autores"].str.split(",").str[0].str.strip()
print(ids_revisados.tolist())
print(f"\nEstudios extraídos: {len(studies_df)}")
print(studies_df["author"].tolist())
# Out:
# ['Kim D', 'Yogo T', 'Zhao L', 'Huang J', 'Huang XF', 'Ishiguro K', 'Muchtar E', 'Boynton SJ', 'Kastritis E', 'Granzow M', 'Ma Q', 'Xie W', 'Yan W']
#
# Estudios extraídos: 13
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %%
import os
studies_df = pd.read_csv(
    r"C:\Users\axdrx\OneDrive\Escritorio\TFM\Extraccion\tabla_estudios.csv",
    encoding='utf-8-sig'
)
print(studies_df["article_id"].tolist())
print(f"Estudios extraídos: {len(studies_df)}")
# Out:
# ['Kim2019', 'Yogo2019', 'Zhao2015', 'Huang2024', 'Huang2019', 'Ishiguro2017', 'Muchtar2017', 'Boynton2016', 'Kastritis2018', 'Granzow2017', 'Ma2024', 'Xie2025', 'Yan2025']
# Estudios extraídos: 13

# %%
# Buscar Xiao en reviewed y procesarlo desde ahí
include_temp = reviewed[reviewed["Autores"].str.contains("Xiao", case=False, na=False)]
print(include_temp[["Título", "Autores"]])
# Out:
# Empty DataFrame
# Columns: [Título, Autores]
# Index: []

# %%
original = pd.read_csv(
    r"C:\Users\axdrx\OneDrive\Escritorio\TFM\Extraccion\estudios_definitivos.csv",
    encoding='utf-8-sig'
)
xiao = original[original["Autores"].str.contains("Xiao", case=False, na=False)]
print(xiao)
# Out:
#                                               Título                   DOI  \
# 8  Prognostic Value of Circulating sST2 for the P...  10.3390/jcdd11070202
#
#                                Autores
# 8  Xiao Y, Liu Y, Fang Q, Tian Z, Li J

# %%
include = pd.concat([include, xiao], ignore_index=True)

include, reviewed, studies_df = mf.review(
    "Xiao", include, reviewed, studies_df)
# Out:
# Título: Prognostic Value of Circulating sST2 for the Prediction of Mortality in Patients With Cardiac Light-Chain Amyloidosis
# Autor:  Xiao Y, Liu Y, Fang Q, Tian Z, Li J
# DOI:    10.3390/jcdd11070202
# ¿Extraer datos de este artículo? (y/n):  y
# ── Tabla de características generales ───────────────
# Año de publicación:  2021
# Revista:  Frontiers in Cardiovascular Medicine
# Diseño del estudio:  Estudio de cohortes
# Subgrupos de pacientes (ej. n=50 AL, n=20 controles sanos, n=15 MGUS):  n=56 pacientes con amiloidosis AL
# Técnicas utilizadas:  Proteómica: Inmunoensayo (ELISA), espectrofotometría
# ✓ Estudio añadido: Xiao2021
#
# ── Tabla de biomarcadores ───────────────────────────
#
# Biomarcador de Xiao2021:
# Nombre/s del biomarcador:  sST2 (Supresor Soluble de la Tumorigenicidad 2)
# Tipo (proteómico/genómico/imagen/circulante/panel):  Proteómico
# Tipo de muestra (suero/plasma/orina/tejido/imagen):  Suero
# ...
